# %%
import tensorflow as tf
import matplotlib.pyplot as plt
import torch
import numpy as np
(X_train, y_train), (X_test, y_test) = tf.keras.datasets.mnist.load_data()
X_train_flatten = np.array(torch.from_numpy(X_train).flatten(1))
X_test_flatten = np.array(torch.from_numpy(X_test).flatten(1))

# %%
plt.imshow(X_train[0])
plt.show()

# %%
torch.repeat(X_train[0])
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 torch.repeat(X_train[0], 3)
#
# File /opt/homebrew/anaconda3/envs/hobbang/lib/python3.10/site-packages/torch/__init__.py:2005, in __getattr__(name)
#    2002     import importlib
#    2003     return importlib.import_module(f".{name}", __name__)
# -> 2005 raise AttributeError(f"module '{__name__}' has no attribute '{name}'")
#
# AttributeError: module 'torch' has no attribute 'repeat'

# %%
torch.tensor(X_train[0]).shape
# Out:
# torch.Size([28, 28])

# %%
tensor=torch.tensor(X_train[0])
tensor.shape
# Out:
# torch.Size([28, 28])

# %%
tensor.unsqueeze(2).shape
# Out:
# torch.Size([28, 28, 1])

# %%
plt.imshow(tensor.unsqueeze(2).repeat(1,1,3))
plt.show()
