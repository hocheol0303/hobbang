# %% [markdown]
# ### 과제 개요
# 본 과제에서는 6강에서 학습한 이미지 Augmentation 및 Text 전처리 개념을 이해하고 스스로 다양한 기법들을 자유자재로 다룰 수 있도록 학습하는 것을 목표로 합니다. 수행할 과제는 다양한 Augmentation 목적에 맞는 적절한 라이브러리 사용 및 텍스트 전처리를 위한 정규표현식의 사용입니다.

# %% [markdown]
# ### 과제 출제 목적 및 배경
# AI 학습 시 정확도를 높이기 위한 다양한 스킬들이 존재합니다. 그 중 이미지 데이터의 경우 데이터를 늘리기 위해 이미지 Augmentation 기법을 자주 사용합니다. 텍스트 데이터의 경우 크롤링한 데이터를 전처리하기 위해 정규표현식을 활용한 전처리를 자주 수행합니다. 이렇듯 다양한 데이터 형태에 따라 모델 성능 향상을 위한 적절한 전처리 기법을 학습합니다.

# %% [markdown]
# ### 과제 수행으로 얻어갈 수 있는 역량
# 이미지 데이터 및 텍스트 데이터의 성능을 향상시킬 수 있는 기법들에 대해 이해하고, 관련된 코딩 역량을 얻을 수 있습니다.

# %% [markdown]
# ### 데이터셋 개요 및 저작권 정보
# 학습에 사용하는 데이터셋은 cifar10 데이터셋으로 10개의 클래스와 60,000개의 32x32 컬러 이미지로 구성되며 클래스당 이미지는 6000개입니다. 비행기, 자동차, 새, 고양이, 사슴, 개, 개구리, 말, 배, 트럭 이미지가 포함되어 있으며 keras 라이브러리에서 데이터셋을 쉽게 호출할 수 있습니다.

# %% [markdown]
# ### 과제 핵심 내용
# 주어진 설명에 맞는 코드를 빈칸에 채워넣어 주세요.

# %% [markdown]
# ### (1) Image Augmentation

# %%
from tensorflow import keras #데이터셋 호출을 위한 keras 라이브러리
import matplotlib.pyplot as plt #이미지 시각화를 위한 matplot 라이브러리
import numpy as np #벡터 차원 조정 및 array 변환을 위한 numpy 라이브러리
from torchvision import transforms #이미지 색상조정을 위한 torchvision 라이브러리
from PIL import Image # transforms 사용을 위한 PIL 라이브러리
import albumentations #이미지 조작을 위한 라이브러리 호출
# %matplotlib inline

# %%
mnist = keras.datasets.cifar10 #cifar10 데이터셋 불러오기
(x_train, y_train), (x_test, y_test) = mnist.load_data() #cifar10 데이터 로드, train/test 셋을 나누어 불러오며 X에는 이미지, Y에는 라벨링 데이터가 담김
test_image = x_train[0] #train 이미지의 0번째 인덱스에 해당하는 이미지를 변수에 저장
test_image_np = np.array(test_image)
test_image = Image.fromarray(test_image)
plt.imshow(test_image)
plt.show() #변수에 저장한 이미지 시각화.

# %% [markdown]
# 1. Transforms 라이브러리를 활용하여 이미지를 augmentation 하려 합니다. 밝기, 대비도, 채도, 색상을 조정한 4개의 증강된 이미지를 만들기 위해 비어있는 코드를 채워주세요.

# %%
#Transforms 라이브러리를 활용하여 이미지를 augmentation 하려 합니다.
#밝기, 대비도, 채도, 색상을 조정한 4개의 증강된 이미지를 만들기 위해 비어있는 코드를 채워주세요.

fig, ax = plt.subplots(2, 2, figsize=(9, 9)) #한 번에 4개의 데이터 호출을 위한 subplot 할당 공간 생성

# TODO : ColorJitter를 활용하여 코드를 채워주세요.
# 밝기조정을 위한 함수입니다. 코드를 채워주세요 (밝기 설정은 자유롭게 진행해주세요.)
# 대비도조정을 위한 함수입니다. 코드를 채워주세요 (대비도 설정은 자유롭게 진행해주세요.)
# 채도조정을 위한 함수입니다. 코드를 채워주세요 (채도 설정은 자유롭게 진행해주세요.)
# 색상조정을 위한 함수입니다. 코드를 채워주세요 (색상 설정은 자유롭게 진행해주세요.)

aug_img1 = # "코드를 채워주세요"
aug_img2 = # "코드를 채워주세요"
aug_img3 = # "코드를 채워주세요"
aug_img4 = # "코드를 채워주세요"

ax[0, 0].imshow(aug_img1)
ax[0, 1].imshow(aug_img2)
ax[1, 0].imshow(aug_img3)
ax[1, 1].imshow(aug_img4)

# %% [markdown]
# 2. Albumentation 라이브러리를 활용하여 이미지를 augmentation 하려 합니다. transform 메서드를 활용하여 원본 이미지와 증강된 이미지를 나란히 시각화하기 위한 함수 코드를 완성해주세요.

# %%
#Albumentation 라이브러리를 활용하여 이미지를 augmentation 하려 합니다.
#transform 메서드를 활용하여 원본 이미지와 증강된 이미지를 나란히 시각화하기 위한 함수 코드를 완성해주세요.

def transform(transform_method):
    """
    TODO : 코드를 채워주세요
    """
    plt.show()

# %%
#함수 작동 확인
transform1 = albumentations.HorizontalFlip(p=1) #입력 이미지의 좌우 반전
transform(transform1)

# %% [markdown]
# ### (2) 정규표현식

# %% [markdown]
# 3. 주어진 text를 정규표현식을 활용해서 E-mail, URL, 한글 자음/모음으로만 이루어진 글자, 특수기호를 제거하려 합니다. 빈 칸을 채워 함수를 완성해주세요.

# %%
#주어진 text를 정규표현식을 활용해서 E-mail, URL, 한글 자음/모음으로만 이루어진 글자, 특수기호를 제거하려 합니다. 빈 칸을 채워 함수를 완성해주세요.

import re
text= '''김철수는 1980년에 태어난 대한민국 국민으로, 한국에서 자랐지만 외국으로 건너가는 것을 꿈꿨습니다. 그는 새로운 문화와 언어를 탐험하며 세계적인 모험을 즐깁니다.
열정적이고 창의적인 성격으로, 항상 새로운 도전에 열려 있습니다. 끊임없이 배우고 성장하며, 자신의 이야기를 통해 다양한 사람들과 소통하는 것을 즐깁니다.
김철수는 풍부한 경험과 넓은 시야를 갖춘 글로벌 시민으로서, 세계를 무대로 활약하는 모습을 보여줍니다.
기자: 홍길동, 이메일: gildong@google.com, 홈페이지: gildong@naver.com
'''


def clean_str(text):
    '''
    TODO : 코드를 채워주세요
    '''
    return text

# %%
#함수 작동 확인
print(text)
print(clean_str(text))
# Out:
# 김철수는 1980년에 태어난 대한민국 국민으로, 한국에서 자랐지만 외국으로 건너가는 것을 꿈꿨습니다. 그는 새로운 문화와 언어를 탐험하며 세계적인 모험을 즐깁니다.
# 열정적이고 창의적인 성격으로, 항상 새로운 도전에 열려 있습니다. 끊임없이 배우고 성장하며, 자신의 이야기를 통해 다양한 사람들과 소통하는 것을 즐깁니다.
# 김철수는 풍부한 경험과 넓은 시야를 갖춘 글로벌 시민으로서, 세계를 무대로 활약하는 모습을 보여줍니다.
# 기자: 홍길동, 이메일: gildong@google.com, 홈페이지: gildong@naver.com
#
# 김철수는 1980년에 태어난 대한민국 국민으로 한국에서 자랐지만 외국으로 건너가는 것을 꿈꿨습니다 그는 새로운 문화와 언어를 탐험하며 세계적인 모험을 즐깁니다 .열정적이고 창의적인 성격으로 항상 새로운 도전에 열려 있습니다 끊임없이 배우고 성장하며 자신의 이야기를 통해 다양한 사람들과 소통하는 것을 즐깁니다 .김철수는 풍부한 경험과 넓은 시야를 갖춘 글로벌 시민으로서 세계를 무대로 활약하는 모습을 보여줍니다.기자 홍길동 이메일  홈페이지 .

# %% [markdown]
# ### Required Package
# - numpy==1.26.3
# - tensorflow==2.15.0
# - albumentations==1.3.1
# - pillow==10.2.0
# - torch==2.1.2
# - matplotlib==0.1.6

# %% [markdown]
# ### **콘텐츠 라이선스**
#
# <font color='red'><b>**WARNING**</b></font> : **본 교육 콘텐츠의 지식재산권은 재단법인 네이버커넥트에 귀속됩니다. 본 콘텐츠를 어떠한 경로로든 외부로 유출 및 수정하는 행위를 엄격히 금합니다.** 다만, 비영리적 교육 및 연구활동에 한정되어 사용할 수 있으나 재단의 허락을 받아야 합니다. 이를 위반하는 경우, 관련 법률에 따라 책임을 질 수 있습니다.
