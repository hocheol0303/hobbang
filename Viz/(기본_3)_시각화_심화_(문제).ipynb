# %% [markdown]
# ### 과제 개요
# 본 과제에서는 7강에서 학습한 다양한 고급시각화 기법에 대해 이해하고 스스로 다양한 그래프들을 자유자재로 다룰 수 있도록 학습하는 것을 목표로 합니다. 수행할 과제는 주어진 데이터셋을 활용한 다양한 시각화 기법의 실습입니다.

# %% [markdown]
# ### 과제 출제 목적 및 배경
# 이전 과제들을 통해 기본적인 탐색적 데이터 분석과 비교시각화를 위한 기법들에 대해 학습했습니다. 본 과제를 통해서는 고급시각화 기법을 학습하여 시각화 목적에 맞게 표현력을 극대화하는 방법을 학습합니다.

# %% [markdown]
# ### 과제 수행으로 얻어갈 수 있는 역량
# 기본 그래프에 더해 다양한 고급시각화 기법들을 학습합니다. 데이터의 결측치를 파악하고 결측치를 시각화하기 위한 라이브러리 사용법을 학습합니다.

# %% [markdown]
# ### 데이터셋 개요 및 저작권 정보
# 학습에 사용하는 데이터셋은 titanic 데이터셋으로 타이타닉 호에 탑승했던 승객들의 정보 및 생존 여부가 담겨있습니다. 어떤 특성을 가진 승객이 더 생존률이 높았는지 머신러닝을 활용해 예측하는 데에 주로 사용됩니다. 15개의 열과 891개 행으로 이루어져있으며 seaborn 라이브러리에서 데이터셋을 쉽게 호출할 수 있습니다.

# %% [markdown]
# ### 과제 핵심 내용
# 주어진 설명에 맞는 코드를 빈칸에 채워넣어 주세요.

# %% [markdown]
# ### (1) 데이터셋 불러오기 및 특성 확인

# %%
#데이터를 불러온 후 데이터 확인
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

titanic = sns.load_dataset('titanic')
print(titanic.head())
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False
# 2  woman       False  NaN  Southampton   yes   True
# 3  woman       False    C  Southampton   yes  False
# 4    man        True  NaN  Southampton    no   True

# %% [markdown]
# 1. 성별에 따른 'alive' 분포를 파이차트로 표현하려 합니다. 각 label은 'female_dead', 'female_alive', 'mail_dead', 'male_alive'로 지정합니다. startangle은 90으로 지정하고 explode를 통해 강조하고 싶은 부분을 강조해주세요. 그리고 차트에는 그림자를 넣고 소숫점 첫째자리까지 퍼센트 형태로 값을 그래프 안에 포함해주세요.

# %%
# 1. 성별에 따른 'alive' 분포를 파이차트로 표현하려 합니다.
# 각 label은 'female_dead', 'female_alive', 'mail_dead', 'male_alive'로 지정합니다.
# startangle은 90으로 지정하고 explode를 통해 강조하고 싶은 부분을 강조해주세요.
# 그리고 차트에는 그림자를 넣고 소숫점 첫째자리까지 퍼센트 형태로 값을 그래프 안에 포함해주세요.

group = # TODO : '코드를 채워주세요'
display(group)

labels = # TODO : '코드를 채워주세요'

fig, ax =

'''
TODO : 코드를 채워주세요
'''

plt.show()
# Out:
# sex     alive
# female  no        81
#         yes      233
# male    no       468
#         yes      109
# Name: count, dtype: int64

# %% [markdown]
# 2. titanic의 칼럼별 null값 정보를 확인하려 합니다. 먼저 칼럼별 non-null 데이터 수를 파악하고, 반대로 null값의 수를 파악하여 출력합니다. 그 후 missingno 라이브러리를 활용하여 데이터내에 포함된 null값을 시각화로 표현해주세요.

# %%
# 2. titanic의 칼럼별 null값 정보를 확인하려 합니다.
# 먼저 칼럼별 non-null 데이터 수를 파악하고, 반대로 null값의 수를 파악하여 출력합니다.
# 그 후 missingno 라이브러리를 활용하여 데이터내에 포함된 null값을 시각화로 표현해주세요.

import missingno as msno

data = # TODO : '코드를 채워주세요'
num_nul = # TODO : '코드를 채워주세요'
msno_plot = # TODO : '코드를 채워주세요'

print(data)
print(num_nul)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 15 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   survived     891 non-null    int64
#  1   pclass       891 non-null    int64
#  2   sex          891 non-null    object
#  3   age          714 non-null    float64
#  4   sibsp        891 non-null    int64
#  5   parch        891 non-null    int64
#  6   fare         891 non-null    float64
#  7   embarked     889 non-null    object
#  8   class        891 non-null    category
#  9   who          891 non-null    object
#  10  adult_male   891 non-null    bool
#  11  deck         203 non-null    category
#  12  embark_town  889 non-null    object
#  13  alive        891 non-null    object
#  14  alone        891 non-null    bool
# dtypes: bool(2), category(2), float64(2), int64(4), object(5)
# memory usage: 80.7+ KB
# None
# survived         0
# pclass           0
# sex              0
# ...

# %% [markdown]
# 3. 생존자와 사망자 수를 비교하는 시각화를 수행하려 합니다. 메인 그래프는 bar 그래프로 그리고, 우측 상단에 작게 pie 차트를 추가하려 합니다. 변수는 생존자 수를 survived_count에 담아 활용합니다. color는 두 그래프 모두 blue와 red로 지정하고, bar 그래프의 경우 xlabel을 'dead'와 'alive'로, ylabel은 'count'로 지정합니다. pie차트는 startangle을 90으로 설정 후 내부에 정수형태의 퍼센트로 비율을 나타냅니다.

# %%
# 3. 생존자와 사망자 수를 비교하는 시각화를 수행하려 합니다. 메인 그래프는 bar 그래프로 그리고, 우측 상단에 작게 pie 차트를 추가하려 합니다.
# 변수는 생존자 수를 survived_count에 담아 활용합니다.
# color는 두 그래프 모두 blue와 red로 지정하고, bar 그래프의 경우 xlabel을 'dead'와 'alive'로, ylabel은 'count'로 지정합니다.
# pie차트는 startangle을 90으로 설정 후 내부에 정수형태의 퍼센트로 비율을 나타냅니다.

survived_count = # TODO : '코드를 채워주세요'

fig, ax =

'''
TODO : 코드를 채워주세요
'''

#파이차트 inset_axes 설정은 [0.8, 0.8, 0.2, 0.2]를 기준으로 해주세요.

plt.show()

# %% [markdown]
# ### Required Package
# - seaborn==0.13.1
# - matplotlib==0.1.6
# - pandas==2.2.0
# - missingno==0.5.2

# %% [markdown]
# ### **콘텐츠 라이선스**
#
# <font color='red'><b>**WARNING**</b></font> : **본 교육 콘텐츠의 지식재산권은 재단법인 네이버커넥트에 귀속됩니다. 본 콘텐츠를 어떠한 경로로든 외부로 유출 및 수정하는 행위를 엄격히 금합니다.** 다만, 비영리적 교육 및 연구활동에 한정되어 사용할 수 있으나 재단의 허락을 받아야 합니다. 이를 위반하는 경우, 관련 법률에 따라 책임을 질 수 있습니다.
