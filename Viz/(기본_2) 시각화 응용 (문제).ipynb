# %% [markdown]
# ### 과제 개요
# 본 과제에서는 4강에서 학습한 정형데이터의 특징 및 비교시각화 기법들을 이해하고 스스로 다양한 그래프들을 자유자재로 다룰 수 있도록 학습하는 것을 목표로 합니다. 수행할 과제는 주어진 데이터셋을 활용한 상관계수 구하기 및 다양한 시각화 기법의 실습입니다.

# %% [markdown]
# ### 과제 출제 목적 및 배경
# 시각화는 데이터 분석 이후 결과를 나타내기 위해 사용되기도 하지만, 데이터 분석 전 데이터의 특성을 파악하기 위해서도 사용됩니다. 간단한 plot으로 데이터를 시각화하여 탐색적 데이터 분석을 수행한 다음에는 데이터의 속성 간 연관성 등을 파악하기 위한 시각화가 요구됩니다. 본 과제는 데이터의 속성 간 연관성을 파악하고 비교시각화 역량을 갖추는 것을 목표로 합니다.

# %% [markdown]
# ### 과제 수행으로 얻어갈 수 있는 역량
# seaborn 라이브러리에서 데이터를 호출 후 데이터프레임의 속성 간 관계를 파악하고 시각화합니다. 데이터의 속성별 비교를 위한 비교시각화 기법 또한 학습할 수 있습니다.

# %% [markdown]
# ### 데이터셋 개요 및 저작권 정보
# 학습에 사용하는 데이터셋은 titanic 데이터셋으로 타이타닉 호에 탑승했던 승객들의 정보 및 생존 여부가 담겨있습니다. 어떤 특성을 가진 승객이 더 생존률이 높았는지 머신러닝을 활용해 예측하는 데에 주로 사용됩니다. 15개의 열과 891개 행으로 이루어져있으며 seaborn 라이브러리에서 데이터셋을 쉽게 호출할 수 있습니다.

# %% [markdown]
# ### 과제 핵심 내용
# 주어진 설명에 맞는 코드를 빈칸에 채워넣어 주세요.

# %% [markdown]
# ### (1) 데이터셋 불러오기 및 특성 확인

# %%
#데이터를 불러온 후 데이터 확인
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

titanic = sns.load_dataset('titanic') 
print(titanic.head())
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False
# 2  woman       False  NaN  Southampton   yes   True
# 3  woman       False    C  Southampton   yes  False
# 4    man        True  NaN  Southampton    no   True

# %% [markdown]
# 1. (14, 5) 크기의 subplot을 만들어 내부에서 두 countplot을 시각화하려 합니다. 첫 번째 그래프에서는 성별을 색상에 따라 구분하여 생존자의 수를 시각화하고, 두 번째 그래프에서는 class를 색상별로 구분하여 생존자의 수를 시각화하려 합니다. 두 번째 그래프는 좀 더 명확한 구분을 위해 색상을 'dark:red'로 설정해주세요.

# %%
# 1. (14, 5) 크기의 subplot을 만들어 내부에서 두 countplot을 시각화하려 합니다.
# 첫 번째 그래프에서는 성별을 색상에 따라 구분하여 생존자의 수를 시각화하고, 두 번째 그래프에서는 class를 색상별로 구분하여 생존자의 수를 시각화하려 합니다.
# 두 번째 그래프는 좀 더 명확한 구분을 위해 색상을 'dark:red'로 설정해주세요. 

fig, axes = 

'''
TODO : 코드를 채워주세요
'''

plt.show()
# Out:
# /Users/jun/Desktop/PythonWorkspace/ch1/lib/python3.11/site-packages/seaborn/_base.py:949: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)
# /Users/jun/Desktop/PythonWorkspace/ch1/lib/python3.11/site-packages/seaborn/_base.py:949: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)
# /Users/jun/Desktop/PythonWorkspace/ch1/lib/python3.11/site-packages/seaborn/_base.py:949: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
# ...

# %% [markdown]
# 2. titanic 데이터셋의 상관계수를 heatmap으로 표현하려 합니다. (14, 7)크기의 subplot을 생성하여 subplot 내에서 두 개의 heatmap을 좌우로 나란히 비교합니다. 두 heatmap은 각각 'pearson'과 'spearman' 방식을 사용하며 수치형 데이터만 비교합니다. 색상의 범위는 -1~1로 지정하며 center 역시 0으로 지정해주세요. heatmap 내부에는 값을 표현하며 소숫점 2번째 자리까지 표기합니다.

# %%
# 2. titanic 데이터셋의 상관계수를 heatmap으로 표현하려 합니다. (14, 7)크기의 subplot을 생성하여 subplot 내에서 두 개의 heatmap을 좌우로 나란히 비교합니다.
# 두 heatmap은 각각 'pearson'과 'spearman' 방식을 사용하며 수치형 데이터만 비교합니다.
# 색상의 범위는 -1~1로 지정하며 center 역시 0으로 지정해주세요. heatmap 내부에는 값을 표현하며 소숫점 2번째 자리까지 표기합니다.
fig, axes = 

'''
TODO : 코드를 채워주세요
'''

plt.show()

# %% [markdown]
# 3. 타이타닉 데이터셋의 통계량을 구해보려 합니다. 칼럼별 최솟값, 최댓값, 평균 및 사분위수를 구하여 statistics 변수에 담아 확인합니다. 그 후 탑승자들의 나이분포 및 이상치를 파악하기 위해 (12, 5) 크기의 figure를 만들고 boxplot을 시각화해주세요. (특정 메서드를 활용해서 한 번에 구할 수 있습니다!)

# %%
# 타이타닉 데이터셋의 통계량을 구해보려 합니다. 칼럼별 최솟값, 최댓값, 평균 및 사분위수를 구하여 statistics 변수에 담아 확인합니다. 
# 그 후 탑승자들의 나이분포 및 이상치를 파악하기 위해 (12, 5) 크기의 figure를 만들고 boxplot을 시각화해주세요. (특정 메서드를 활용해서 한 번에 구할 수 있습니다!)
statistics = # TODO : '코드를 채워주세요'

fig, ax = 

'''
TODO : 코드를 채워주세요
'''

plt.show()
print(statistics)
# Out:
# /Users/jun/Desktop/PythonWorkspace/ch1/lib/python3.11/site-packages/seaborn/categorical.py:640: FutureWarning: SeriesGroupBy.grouper is deprecated and will be removed in a future version of pandas.
#   positions = grouped.grouper.result_index.to_numpy(dtype=float)
#          survived      pclass         age       sibsp       parch        fare
# count  891.000000  891.000000  714.000000  891.000000  891.000000  891.000000
# mean     0.383838    2.308642   29.699118    0.523008    0.381594   32.204208
# std      0.486592    0.836071   14.526497    1.102743    0.806057   49.693429
# min      0.000000    1.000000    0.420000    0.000000    0.000000    0.000000
# 25%      0.000000    2.000000   20.125000    0.000000    0.000000    7.910400
# 50%      0.000000    3.000000   28.000000    0.000000    0.000000   14.454200
# 75%      1.000000    3.000000   38.000000    1.000000    0.000000   31.000000
# max      1.000000    3.000000   80.000000    8.000000    6.000000  512.329200

# %% [markdown]
# ### Required Package
# - seaborn==0.13.1
# - matplotlib==0.1.6
# - pandas==2.2.0
# - scipy==1.12.0

# %% [markdown]
# ### **콘텐츠 라이선스**
#
# <font color='red'><b>**WARNING**</b></font> : **본 교육 콘텐츠의 지식재산권은 재단법인 네이버커넥트에 귀속됩니다. 본 콘텐츠를 어떠한 경로로든 외부로 유출 및 수정하는 행위를 엄격히 금합니다.** 다만, 비영리적 교육 및 연구활동에 한정되어 사용할 수 있으나 재단의 허락을 받아야 합니다. 이를 위반하는 경우, 관련 법률에 따라 책임을 질 수 있습니다.
